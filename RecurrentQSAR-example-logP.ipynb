# %% [markdown]
# ## Predicting logP with RNNs and SMILES strings

# %% [markdown]
# This notebook demonstrates how to build predictive recurrent neural network for SMILES strings. We will build regression model for logP with OpenChem Toolkit (https://github.com/Mariewelt/OpenChem)

# %%
# Cloning OpenChem. Comment this line if you already cloned the repository
! git clone https://github.com/Mariewelt/OpenChem.git

# %% [markdown]
# ## Imports

# %%
import sys
import os

# %%
sys.path.append('./OpenChem')

# %%
from openchem.models.Smiles2Label import Smiles2Label
from openchem.modules.encoders.rnn_encoder import RNNEncoder
from openchem.modules.mlp.openchem_mlp import OpenChemMLP
from openchem.data.smiles_data_layer import SmilesDataset
from openchem.data.utils import save_smiles_property_file
from openchem.data.utils import create_loader
from openchem.models.openchem_model import build_training, fit, evaluate

# %%
import torch.nn as nn
from torch.optim import RMSprop, SGD, Adam
from torch.optim.lr_scheduler import ExponentialLR, StepLR
import torch.nn.functional as F

# %%
from sklearn.metrics import r2_score
import pandas as pd
import copy
import pickle

# %% [markdown]
# ## Reading data

# %%
from openchem.data.utils import read_smiles_property_file
data = read_smiles_property_file('./data/logP_labels.csv', 
                                 cols_to_read=[1, 2])
smiles = data[0]
labels = data[1]

# %%
from openchem.data.utils import get_tokens
tokens, _, _ = get_tokens(smiles)
tokens = tokens + ' '

# %% [markdown]
# ## Model architecture

# %% [markdown]
# Here we define the architecture of our Recurrent Neural Network (RNN). We will use 2 LSTM layers. For more details on how to build models with OpenChem, visit: https://mariewelt.github.io/OpenChem/

# %%
import torch
from openchem.utils.utils import identity
from openchem.modules.embeddings.basic_embedding import Embedding
model_object = Smiles2Label

model_params = {
    'use_cuda': True,
    'random_seed': 42,
    'world_size': 1,
    'task': 'regression',
    'data_layer': SmilesDataset,
    'use_clip_grad': False,
    'batch_size': 128,
    'num_epochs': 51,
    'logdir': './logs/logp_logs',
    'print_every': 1,
    'save_every': 5,
    #'train_data_layer': train_dataset,
    #'val_data_layer': test_dataset,
    'eval_metrics': r2_score,
    'criterion': nn.MSELoss(),
    'optimizer': Adam,
    'optimizer_params': {
        'lr': 0.005,
    },
    'lr_scheduler': StepLR,
    'lr_scheduler_params': {
        'step_size': 15,
        'gamma': 0.8
    },
    'embedding': Embedding,
    'embedding_params': {
        'num_embeddings': len(tokens),
        'embedding_dim': 128,
        'padding_idx': tokens.index(' ')
    },
    'encoder': RNNEncoder,
    'encoder_params': {
        'input_size': 128,
        'layer': "LSTM",
        'encoder_dim': 128,
        'n_layers': 2,
        'dropout': 0.8,
        'is_bidirectional': False
    },
    'mlp': OpenChemMLP,
    'mlp_params': {
        'input_size': 128,
        'n_layers': 2,
        'hidden_size': [128, 1],
        'activation': [F.relu, identity],
        'dropout': 0.0
    }
}

# %%
try:
    os.stat(model_params['logdir'])
except:
    os.mkdir(model_params['logdir'])

# %% [markdown]
# ## Initializing data splitter for cross validation

# %%
from sklearn.model_selection import KFold
cross_validation_split = KFold(n_splits=5, shuffle=True)

# %%
data = cross_validation_split.split(smiles, labels)

# %% [markdown]
# ## Training cross-validated models

# %%
import os
i = 0
models = []
results = []
for split in data:
    print('Cross validation, fold number ' + str(i) + ' in progress...')
    train, test = split
    X_train = smiles[train]
    y_train = labels[train]
    X_test = smiles[test]
    y_test = labels[test]
    save_smiles_property_file('./data/logp_train_fold' + str(i) + '.smi', 
                              X_train, y_train.reshape(-1, 1))
    save_smiles_property_file('./data/logp_test_fold' + str(i) + '.smi', 
                              X_test, y_test.reshape(-1, 1))

    train_dataset = SmilesDataset('./data/logp_train_fold' + str(i) + '.smi',
                           delimiter=',', cols_to_read=[0, 1], tokens=tokens)
    test_dataset = SmilesDataset('./data/logp_test_fold' + str(i) + '.smi',
                       delimiter=',', cols_to_read=[0, 1], tokens=tokens)
    model_params['train_data_layer'] = train_dataset
    model_params['val_data_layer'] = test_dataset
    model_params['logdir'] = './logs/logp_logs/fold' + str(i)  
    logdir = model_params['logdir']
    ckpt_dir = logdir + '/checkpoint/'
    try:
        os.stat(ckpt_dir)
    except:
        os.mkdir(logdir)
        os.mkdir(ckpt_dir)
    train_loader = create_loader(train_dataset,
                             batch_size=model_params['batch_size'],
                             shuffle=True,
                             num_workers=4,
                             pin_memory=True,
                             sampler=None)
    val_loader = create_loader(test_dataset,
                           batch_size=model_params['batch_size'],
                           shuffle=False,
                           num_workers=1,
                           pin_memory=True)
    models.append(model_object(params=model_params).cuda())
    criterion, optimizer, lr_scheduler = build_training(models[i], model_params)
    results.append(fit(models[i], lr_scheduler, train_loader, optimizer, criterion,
        model_params, eval=True, val_loader=val_loader))
    
    i = i+1
# Out:
# Cross validation, fold number 0 in progress...
# TRAINING: [Time: 0m 2s, Epoch: 0, Progress: 0%, Loss: 2.2958]
# EVALUATION: [Time: 0m 0s, Loss: 1.3561, Metrics: 0.5885]
# TRAINING: [Time: 0m 5s, Epoch: 1, Progress: 1%, Loss: 1.0152]
# EVALUATION: [Time: 0m 0s, Loss: 0.5825, Metrics: 0.8231]
# TRAINING: [Time: 0m 7s, Epoch: 2, Progress: 3%, Loss: 0.7186]
# EVALUATION: [Time: 0m 0s, Loss: 0.7800, Metrics: 0.7640]
# TRAINING: [Time: 0m 10s, Epoch: 3, Progress: 5%, Loss: 0.6039]
# EVALUATION: [Time: 0m 0s, Loss: 0.5324, Metrics: 0.8384]
# TRAINING: [Time: 0m 12s, Epoch: 4, Progress: 7%, Loss: 0.5563]
# EVALUATION: [Time: 0m 0s, Loss: 0.4946, Metrics: 0.8499]
# TRAINING: [Time: 0m 15s, Epoch: 5, Progress: 9%, Loss: 0.5006]
# EVALUATION: [Time: 0m 0s, Loss: 0.5587, Metrics: 0.8310]
# TRAINING: [Time: 0m 18s, Epoch: 6, Progress: 11%, Loss: 0.4807]
# EVALUATION: [Time: 0m 0s, Loss: 0.4322, Metrics: 0.8676]
# TRAINING: [Time: 0m 20s, Epoch: 7, Progress: 13%, Loss: 0.4437]
# EVALUATION: [Time: 0m 0s, Loss: 0.7048, Metrics: 0.7858]
# TRAINING: [Time: 0m 23s, Epoch: 8, Progress: 15%, Loss: 0.4152]
# EVALUATION: [Time: 0m 0s, Loss: 0.6407, Metrics: 0.8040]
# TRAINING: [Time: 0m 26s, Epoch: 9, Progress: 17%, Loss: 0.3834]
# EVALUATION: [Time: 0m 0s, Loss: 0.3756, Metrics: 0.8848]
# TRAINING: [Time: 0m 28s, Epoch: 10, Progress: 19%, Loss: 0.3649]
# EVALUATION: [Time: 0m 0s, Loss: 0.3322, Metrics: 0.8982]
# TRAINING: [Time: 0m 31s, Epoch: 11, Progress: 21%, Loss: 0.3771]
# EVALUATION: [Time: 0m 0s, Loss: 0.4947, Metrics: 0.8497]
# TRAINING: [Time: 0m 33s, Epoch: 12, Progress: 23%, Loss: 0.3314]
# EVALUATION: [Time: 0m 0s, Loss: 0.3597, Metrics: 0.8904]
# TRAINING: [Time: 0m 36s, Epoch: 13, Progress: 25%, Loss: 0.3325]
# EVALUATION: [Time: 0m 0s, Loss: 0.3472, Metrics: 0.8935]
# TRAINING: [Time: 0m 39s, Epoch: 14, Progress: 27%, Loss: 0.3367]
# EVALUATION: [Time: 0m 0s, Loss: 0.4131, Metrics: 0.8737]
# TRAINING: [Time: 0m 41s, Epoch: 15, Progress: 29%, Loss: 0.3249]
# EVALUATION: [Time: 0m 0s, Loss: 0.3934, Metrics: 0.8810]
# TRAINING: [Time: 0m 44s, Epoch: 16, Progress: 31%, Loss: 0.2897]
# EVALUATION: [Time: 0m 0s, Loss: 0.2771, Metrics: 0.9147]
# TRAINING: [Time: 0m 47s, Epoch: 17, Progress: 33%, Loss: 0.2676]
# EVALUATION: [Time: 0m 0s, Loss: 0.3518, Metrics: 0.8921]
# TRAINING: [Time: 0m 49s, Epoch: 18, Progress: 35%, Loss: 0.2644]
# EVALUATION: [Time: 0m 0s, Loss: 0.2847, Metrics: 0.9127]
# TRAINING: [Time: 0m 52s, Epoch: 19, Progress: 37%, Loss: 0.2654]
# EVALUATION: [Time: 0m 0s, Loss: 0.3325, Metrics: 0.8984]
# TRAINING: [Time: 0m 55s, Epoch: 20, Progress: 39%, Loss: 0.2448]
# EVALUATION: [Time: 0m 0s, Loss: 0.2571, Metrics: 0.9208]
# TRAINING: [Time: 0m 57s, Epoch: 21, Progress: 41%, Loss: 0.2519]
# EVALUATION: [Time: 0m 0s, Loss: 0.2438, Metrics: 0.9247]
# TRAINING: [Time: 1m 0s, Epoch: 22, Progress: 43%, Loss: 0.2586]
# EVALUATION: [Time: 0m 0s, Loss: 0.2640, Metrics: 0.9194]
# TRAINING: [Time: 1m 3s, Epoch: 23, Progress: 45%, Loss: 0.2356]
# EVALUATION: [Time: 0m 0s, Loss: 0.3210, Metrics: 0.9018]
# TRAINING: [Time: 1m 5s, Epoch: 24, Progress: 47%, Loss: 0.2336]
# EVALUATION: [Time: 0m 0s, Loss: 0.2560, Metrics: 0.9215]
# TRAINING: [Time: 1m 8s, Epoch: 25, Progress: 49%, Loss: 0.2185]
# EVALUATION: [Time: 0m 0s, Loss: 0.2805, Metrics: 0.9139]
# TRAINING: [Time: 1m 10s, Epoch: 26, Progress: 50%, Loss: 0.2345]
# EVALUATION: [Time: 0m 0s, Loss: 0.2480, Metrics: 0.9249]
# TRAINING: [Time: 1m 13s, Epoch: 27, Progress: 52%, Loss: 0.2121]
# EVALUATION: [Time: 0m 0s, Loss: 0.3560, Metrics: 0.8932]
# TRAINING: [Time: 1m 16s, Epoch: 28, Progress: 54%, Loss: 0.2123]
# EVALUATION: [Time: 0m 0s, Loss: 0.2436, Metrics: 0.9252]
# TRAINING: [Time: 1m 18s, Epoch: 29, Progress: 56%, Loss: 0.2177]
# EVALUATION: [Time: 0m 0s, Loss: 0.2830, Metrics: 0.9126]
# TRAINING: [Time: 1m 21s, Epoch: 30, Progress: 58%, Loss: 0.2061]
# EVALUATION: [Time: 0m 0s, Loss: 0.2755, Metrics: 0.9154]
# TRAINING: [Time: 1m 24s, Epoch: 31, Progress: 60%, Loss: 0.1966]
# EVALUATION: [Time: 0m 0s, Loss: 0.2538, Metrics: 0.9220]
# TRAINING: [Time: 1m 27s, Epoch: 32, Progress: 62%, Loss: 0.1871]
# EVALUATION: [Time: 0m 0s, Loss: 0.3249, Metrics: 0.9010]
# TRAINING: [Time: 1m 29s, Epoch: 33, Progress: 64%, Loss: 0.1758]
# EVALUATION: [Time: 0m 0s, Loss: 0.2934, Metrics: 0.9099]
# TRAINING: [Time: 1m 32s, Epoch: 34, Progress: 66%, Loss: 0.1803]
# EVALUATION: [Time: 0m 0s, Loss: 0.3104, Metrics: 0.9047]
# TRAINING: [Time: 1m 35s, Epoch: 35, Progress: 68%, Loss: 0.1685]
# EVALUATION: [Time: 0m 0s, Loss: 0.2401, Metrics: 0.9264]
# TRAINING: [Time: 1m 37s, Epoch: 36, Progress: 70%, Loss: 0.1795]
# EVALUATION: [Time: 0m 0s, Loss: 0.2985, Metrics: 0.9087]
# TRAINING: [Time: 1m 40s, Epoch: 37, Progress: 72%, Loss: 0.1681]
# EVALUATION: [Time: 0m 0s, Loss: 0.2362, Metrics: 0.9273]
# TRAINING: [Time: 1m 42s, Epoch: 38, Progress: 74%, Loss: 0.1642]
# EVALUATION: [Time: 0m 0s, Loss: 0.2728, Metrics: 0.9160]
# TRAINING: [Time: 1m 45s, Epoch: 39, Progress: 76%, Loss: 0.1520]
# EVALUATION: [Time: 0m 0s, Loss: 0.3015, Metrics: 0.9077]
# TRAINING: [Time: 1m 48s, Epoch: 40, Progress: 78%, Loss: 0.1642]
# EVALUATION: [Time: 0m 0s, Loss: 0.2480, Metrics: 0.9240]
# TRAINING: [Time: 1m 50s, Epoch: 41, Progress: 80%, Loss: 0.1632]
# EVALUATION: [Time: 0m 0s, Loss: 0.2338, Metrics: 0.9285]
# TRAINING: [Time: 1m 53s, Epoch: 42, Progress: 82%, Loss: 0.1601]
# EVALUATION: [Time: 0m 0s, Loss: 0.2421, Metrics: 0.9254]
# TRAINING: [Time: 1m 55s, Epoch: 43, Progress: 84%, Loss: 0.1626]
# EVALUATION: [Time: 0m 0s, Loss: 0.2399, Metrics: 0.9264]
# TRAINING: [Time: 1m 58s, Epoch: 44, Progress: 86%, Loss: 0.1630]
# EVALUATION: [Time: 0m 0s, Loss: 0.2301, Metrics: 0.9294]
# TRAINING: [Time: 2m 1s, Epoch: 45, Progress: 88%, Loss: 0.1694]
# EVALUATION: [Time: 0m 0s, Loss: 0.2398, Metrics: 0.9263]
# TRAINING: [Time: 2m 3s, Epoch: 46, Progress: 90%, Loss: 0.1501]
# EVALUATION: [Time: 0m 0s, Loss: 0.2562, Metrics: 0.9215]
# TRAINING: [Time: 2m 6s, Epoch: 47, Progress: 92%, Loss: 0.1392]
# EVALUATION: [Time: 0m 0s, Loss: 0.2233, Metrics: 0.9312]
# TRAINING: [Time: 2m 9s, Epoch: 48, Progress: 94%, Loss: 0.1396]
# EVALUATION: [Time: 0m 0s, Loss: 0.2368, Metrics: 0.9281]
# TRAINING: [Time: 2m 11s, Epoch: 49, Progress: 96%, Loss: 0.1373]
# EVALUATION: [Time: 0m 0s, Loss: 0.2358, Metrics: 0.9274]
# TRAINING: [Time: 2m 14s, Epoch: 50, Progress: 98%, Loss: 0.1316]
# EVALUATION: [Time: 0m 0s, Loss: 0.2627, Metrics: 0.9192]
# Cross validation, fold number 1 in progress...
# TRAINING: [Time: 0m 2s, Epoch: 0, Progress: 0%, Loss: 1.8173]
# EVALUATION: [Time: 0m 0s, Loss: 1.1259, Metrics: 0.6849]
# TRAINING: [Time: 0m 5s, Epoch: 1, Progress: 1%, Loss: 0.8299]
# EVALUATION: [Time: 0m 0s, Loss: 0.8562, Metrics: 0.7579]
# TRAINING: [Time: 0m 7s, Epoch: 2, Progress: 3%, Loss: 0.6655]
# EVALUATION: [Time: 0m 0s, Loss: 0.5297, Metrics: 0.8524]
# TRAINING: [Time: 0m 10s, Epoch: 3, Progress: 5%, Loss: 0.5613]
# EVALUATION: [Time: 0m 0s, Loss: 0.6256, Metrics: 0.8214]
# TRAINING: [Time: 0m 13s, Epoch: 4, Progress: 7%, Loss: 0.5227]
# EVALUATION: [Time: 0m 0s, Loss: 0.4516, Metrics: 0.8710]
# TRAINING: [Time: 0m 15s, Epoch: 5, Progress: 9%, Loss: 0.4802]
# EVALUATION: [Time: 0m 0s, Loss: 0.5253, Metrics: 0.8512]
# TRAINING: [Time: 0m 18s, Epoch: 6, Progress: 11%, Loss: 0.4293]
# EVALUATION: [Time: 0m 0s, Loss: 0.3818, Metrics: 0.8919]
# TRAINING: [Time: 0m 21s, Epoch: 7, Progress: 13%, Loss: 0.4165]
# EVALUATION: [Time: 0m 0s, Loss: 0.4413, Metrics: 0.8782]
# TRAINING: [Time: 0m 24s, Epoch: 8, Progress: 15%, Loss: 0.3944]
# EVALUATION: [Time: 0m 0s, Loss: 0.3568, Metrics: 0.8991]
# TRAINING: [Time: 0m 26s, Epoch: 9, Progress: 17%, Loss: 0.3687]
# EVALUATION: [Time: 0m 0s, Loss: 0.4999, Metrics: 0.8600]
# TRAINING: [Time: 0m 29s, Epoch: 10, Progress: 19%, Loss: 0.3660]
# EVALUATION: [Time: 0m 0s, Loss: 0.7382, Metrics: 0.7939]
# TRAINING: [Time: 0m 32s, Epoch: 11, Progress: 21%, Loss: 0.3337]
# EVALUATION: [Time: 0m 0s, Loss: 0.4114, Metrics: 0.8848]
# TRAINING: [Time: 0m 35s, Epoch: 12, Progress: 23%, Loss: 0.3226]
# EVALUATION: [Time: 0m 0s, Loss: 0.3865, Metrics: 0.8889]
# TRAINING: [Time: 0m 37s, Epoch: 13, Progress: 25%, Loss: 0.3150]
# EVALUATION: [Time: 0m 0s, Loss: 0.3179, Metrics: 0.9090]
# TRAINING: [Time: 0m 40s, Epoch: 14, Progress: 27%, Loss: 0.2929]
# EVALUATION: [Time: 0m 0s, Loss: 0.3241, Metrics: 0.9068]
# TRAINING: [Time: 0m 43s, Epoch: 15, Progress: 29%, Loss: 0.3026]
# EVALUATION: [Time: 0m 0s, Loss: 0.3181, Metrics: 0.9101]
# TRAINING: [Time: 0m 46s, Epoch: 16, Progress: 31%, Loss: 0.2810]
# EVALUATION: [Time: 0m 0s, Loss: 0.2730, Metrics: 0.9221]
# TRAINING: [Time: 0m 48s, Epoch: 17, Progress: 33%, Loss: 0.2624]
# EVALUATION: [Time: 0m 0s, Loss: 0.3173, Metrics: 0.9110]
# TRAINING: [Time: 0m 51s, Epoch: 18, Progress: 35%, Loss: 0.2480]
# EVALUATION: [Time: 0m 0s, Loss: 0.2876, Metrics: 0.9191]
# TRAINING: [Time: 0m 54s, Epoch: 19, Progress: 37%, Loss: 0.2460]
# EVALUATION: [Time: 0m 0s, Loss: 0.2733, Metrics: 0.9229]
# TRAINING: [Time: 0m 57s, Epoch: 20, Progress: 39%, Loss: 0.2375]
# EVALUATION: [Time: 0m 0s, Loss: 0.2693, Metrics: 0.9229]
# TRAINING: [Time: 0m 59s, Epoch: 21, Progress: 41%, Loss: 0.2377]
# EVALUATION: [Time: 0m 0s, Loss: 0.2973, Metrics: 0.9142]
# TRAINING: [Time: 1m 2s, Epoch: 22, Progress: 43%, Loss: 0.2322]
# EVALUATION: [Time: 0m 0s, Loss: 0.3000, Metrics: 0.9147]
# TRAINING: [Time: 1m 5s, Epoch: 23, Progress: 45%, Loss: 0.2269]
# EVALUATION: [Time: 0m 0s, Loss: 0.3450, Metrics: 0.9016]
# TRAINING: [Time: 1m 7s, Epoch: 24, Progress: 47%, Loss: 0.2266]
# EVALUATION: [Time: 0m 0s, Loss: 0.3123, Metrics: 0.9110]
# TRAINING: [Time: 1m 10s, Epoch: 25, Progress: 49%, Loss: 0.2001]
# EVALUATION: [Time: 0m 0s, Loss: 0.2721, Metrics: 0.9221]
# TRAINING: [Time: 1m 12s, Epoch: 26, Progress: 50%, Loss: 0.2068]
# EVALUATION: [Time: 0m 0s, Loss: 0.3004, Metrics: 0.9147]
# TRAINING: [Time: 1m 15s, Epoch: 27, Progress: 52%, Loss: 0.2043]
# EVALUATION: [Time: 0m 0s, Loss: 0.3233, Metrics: 0.9074]
# TRAINING: [Time: 1m 18s, Epoch: 28, Progress: 54%, Loss: 0.2015]
# EVALUATION: [Time: 0m 0s, Loss: 0.2788, Metrics: 0.9200]
# TRAINING: [Time: 1m 21s, Epoch: 29, Progress: 56%, Loss: 0.2083]
# EVALUATION: [Time: 0m 0s, Loss: 0.3055, Metrics: 0.9127]
# TRAINING: [Time: 1m 23s, Epoch: 30, Progress: 58%, Loss: 0.1933]
# EVALUATION: [Time: 0m 0s, Loss: 0.2892, Metrics: 0.9176]
# TRAINING: [Time: 1m 26s, Epoch: 31, Progress: 60%, Loss: 0.1878]
# EVALUATION: [Time: 0m 0s, Loss: 0.2648, Metrics: 0.9243]
# TRAINING: [Time: 1m 29s, Epoch: 32, Progress: 62%, Loss: 0.1755]
# EVALUATION: [Time: 0m 0s, Loss: 0.2539, Metrics: 0.9271]
# TRAINING: [Time: 1m 31s, Epoch: 33, Progress: 64%, Loss: 0.1689]
# EVALUATION: [Time: 0m 0s, Loss: 0.2416, Metrics: 0.9302]
# TRAINING: [Time: 1m 34s, Epoch: 34, Progress: 66%, Loss: 0.1689]
# EVALUATION: [Time: 0m 0s, Loss: 0.2582, Metrics: 0.9263]
# TRAINING: [Time: 1m 37s, Epoch: 35, Progress: 68%, Loss: 0.1616]
# EVALUATION: [Time: 0m 0s, Loss: 0.2430, Metrics: 0.9303]
# TRAINING: [Time: 1m 39s, Epoch: 36, Progress: 70%, Loss: 0.1660]
# EVALUATION: [Time: 0m 0s, Loss: 0.2922, Metrics: 0.9158]
# TRAINING: [Time: 1m 42s, Epoch: 37, Progress: 72%, Loss: 0.1747]
# EVALUATION: [Time: 0m 0s, Loss: 0.2700, Metrics: 0.9221]
# TRAINING: [Time: 1m 45s, Epoch: 38, Progress: 74%, Loss: 0.1520]
# EVALUATION: [Time: 0m 0s, Loss: 0.2994, Metrics: 0.9144]
# TRAINING: [Time: 1m 47s, Epoch: 39, Progress: 76%, Loss: 0.1573]
# EVALUATION: [Time: 0m 0s, Loss: 0.2623, Metrics: 0.9255]
# TRAINING: [Time: 1m 50s, Epoch: 40, Progress: 78%, Loss: 0.1499]
# EVALUATION: [Time: 0m 0s, Loss: 0.2803, Metrics: 0.9201]
# TRAINING: [Time: 1m 53s, Epoch: 41, Progress: 80%, Loss: 0.1555]
# EVALUATION: [Time: 0m 0s, Loss: 0.2508, Metrics: 0.9275]
# TRAINING: [Time: 1m 55s, Epoch: 42, Progress: 82%, Loss: 0.1438]
# EVALUATION: [Time: 0m 0s, Loss: 0.2433, Metrics: 0.9301]
# TRAINING: [Time: 1m 58s, Epoch: 43, Progress: 84%, Loss: 0.1483]
# EVALUATION: [Time: 0m 0s, Loss: 0.2386, Metrics: 0.9311]
# TRAINING: [Time: 2m 1s, Epoch: 44, Progress: 86%, Loss: 0.1444]
# EVALUATION: [Time: 0m 0s, Loss: 0.2475, Metrics: 0.9287]
# TRAINING: [Time: 2m 3s, Epoch: 45, Progress: 88%, Loss: 0.1470]
# EVALUATION: [Time: 0m 0s, Loss: 0.2677, Metrics: 0.9236]
# TRAINING: [Time: 2m 6s, Epoch: 46, Progress: 90%, Loss: 0.1353]
# EVALUATION: [Time: 0m 0s, Loss: 0.2814, Metrics: 0.9191]
# TRAINING: [Time: 2m 9s, Epoch: 47, Progress: 92%, Loss: 0.1364]
# EVALUATION: [Time: 0m 0s, Loss: 0.2315, Metrics: 0.9326]
# TRAINING: [Time: 2m 11s, Epoch: 48, Progress: 94%, Loss: 0.1284]
# EVALUATION: [Time: 0m 0s, Loss: 0.2702, Metrics: 0.9232]
# TRAINING: [Time: 2m 14s, Epoch: 49, Progress: 96%, Loss: 0.1271]
# EVALUATION: [Time: 0m 0s, Loss: 0.2302, Metrics: 0.9331]
# TRAINING: [Time: 2m 17s, Epoch: 50, Progress: 98%, Loss: 0.1271]
# EVALUATION: [Time: 0m 0s, Loss: 0.2313, Metrics: 0.9334]
# Cross validation, fold number 2 in progress...
# TRAINING: [Time: 0m 2s, Epoch: 0, Progress: 0%, Loss: 1.8514]
# EVALUATION: [Time: 0m 0s, Loss: 0.8807, Metrics: 0.7309]
# TRAINING: [Time: 0m 5s, Epoch: 1, Progress: 1%, Loss: 0.8116]
# EVALUATION: [Time: 0m 0s, Loss: 1.0538, Metrics: 0.6893]
# TRAINING: [Time: 0m 7s, Epoch: 2, Progress: 3%, Loss: 0.6623]
# EVALUATION: [Time: 0m 0s, Loss: 0.5827, Metrics: 0.8231]
# TRAINING: [Time: 0m 10s, Epoch: 3, Progress: 5%, Loss: 0.5614]
# EVALUATION: [Time: 0m 0s, Loss: 0.5555, Metrics: 0.8320]
# TRAINING: [Time: 0m 13s, Epoch: 4, Progress: 7%, Loss: 0.4867]
# EVALUATION: [Time: 0m 0s, Loss: 0.5529, Metrics: 0.8311]
# TRAINING: [Time: 0m 15s, Epoch: 5, Progress: 9%, Loss: 0.4765]
# EVALUATION: [Time: 0m 0s, Loss: 0.4102, Metrics: 0.8752]
# TRAINING: [Time: 0m 18s, Epoch: 6, Progress: 11%, Loss: 0.4442]
# EVALUATION: [Time: 0m 0s, Loss: 0.4973, Metrics: 0.8495]
# TRAINING: [Time: 0m 21s, Epoch: 7, Progress: 13%, Loss: 0.4180]
# EVALUATION: [Time: 0m 0s, Loss: 0.3959, Metrics: 0.8786]
# TRAINING: [Time: 0m 23s, Epoch: 8, Progress: 15%, Loss: 0.3815]
# EVALUATION: [Time: 0m 0s, Loss: 0.4332, Metrics: 0.8682]
# TRAINING: [Time: 0m 26s, Epoch: 9, Progress: 17%, Loss: 0.3619]
# EVALUATION: [Time: 0m 0s, Loss: 0.4130, Metrics: 0.8738]
# TRAINING: [Time: 0m 29s, Epoch: 10, Progress: 19%, Loss: 0.3667]
# EVALUATION: [Time: 0m 0s, Loss: 0.3766, Metrics: 0.8844]
# TRAINING: [Time: 0m 31s, Epoch: 11, Progress: 21%, Loss: 0.3427]
# EVALUATION: [Time: 0m 0s, Loss: 0.3738, Metrics: 0.8857]
# TRAINING: [Time: 0m 34s, Epoch: 12, Progress: 23%, Loss: 0.3172]
# EVALUATION: [Time: 0m 0s, Loss: 0.4166, Metrics: 0.8734]
# TRAINING: [Time: 0m 37s, Epoch: 13, Progress: 25%, Loss: 0.3878]
# EVALUATION: [Time: 0m 0s, Loss: 0.9097, Metrics: 0.7268]
# TRAINING: [Time: 0m 40s, Epoch: 14, Progress: 27%, Loss: 0.3595]
# EVALUATION: [Time: 0m 0s, Loss: 0.6361, Metrics: 0.8076]
# TRAINING: [Time: 0m 42s, Epoch: 15, Progress: 29%, Loss: 0.3227]
# EVALUATION: [Time: 0m 0s, Loss: 0.3081, Metrics: 0.9064]
# TRAINING: [Time: 0m 45s, Epoch: 16, Progress: 31%, Loss: 0.2779]
# EVALUATION: [Time: 0m 0s, Loss: 0.3151, Metrics: 0.9049]
# TRAINING: [Time: 0m 48s, Epoch: 17, Progress: 33%, Loss: 0.2656]
# EVALUATION: [Time: 0m 0s, Loss: 0.3522, Metrics: 0.8930]
# TRAINING: [Time: 0m 50s, Epoch: 18, Progress: 35%, Loss: 0.2459]
# EVALUATION: [Time: 0m 0s, Loss: 0.2888, Metrics: 0.9115]
# TRAINING: [Time: 0m 53s, Epoch: 19, Progress: 37%, Loss: 0.2383]
# EVALUATION: [Time: 0m 0s, Loss: 0.3247, Metrics: 0.9016]
# TRAINING: [Time: 0m 56s, Epoch: 20, Progress: 39%, Loss: 0.2387]
# EVALUATION: [Time: 0m 0s, Loss: 0.4280, Metrics: 0.8707]
# TRAINING: [Time: 0m 58s, Epoch: 21, Progress: 41%, Loss: 0.2318]
# EVALUATION: [Time: 0m 0s, Loss: 0.2873, Metrics: 0.9126]
# TRAINING: [Time: 1m 1s, Epoch: 22, Progress: 43%, Loss: 0.2297]
# EVALUATION: [Time: 0m 0s, Loss: 0.3198, Metrics: 0.9041]
# TRAINING: [Time: 1m 4s, Epoch: 23, Progress: 45%, Loss: 0.2202]
# EVALUATION: [Time: 0m 0s, Loss: 0.2662, Metrics: 0.9191]
# TRAINING: [Time: 1m 6s, Epoch: 24, Progress: 47%, Loss: 0.2241]
# EVALUATION: [Time: 0m 0s, Loss: 0.2867, Metrics: 0.9136]
# TRAINING: [Time: 1m 9s, Epoch: 25, Progress: 49%, Loss: 0.2197]
# EVALUATION: [Time: 0m 0s, Loss: 0.3025, Metrics: 0.9082]
# TRAINING: [Time: 1m 12s, Epoch: 26, Progress: 50%, Loss: 0.2222]
# EVALUATION: [Time: 0m 0s, Loss: 0.2951, Metrics: 0.9105]
# TRAINING: [Time: 1m 14s, Epoch: 27, Progress: 52%, Loss: 0.2095]
# EVALUATION: [Time: 0m 0s, Loss: 0.2967, Metrics: 0.9099]
# TRAINING: [Time: 1m 17s, Epoch: 28, Progress: 54%, Loss: 0.1972]
# EVALUATION: [Time: 0m 0s, Loss: 0.2840, Metrics: 0.9138]
# TRAINING: [Time: 1m 20s, Epoch: 29, Progress: 56%, Loss: 0.2065]
# EVALUATION: [Time: 0m 0s, Loss: 0.3818, Metrics: 0.8857]
# TRAINING: [Time: 1m 23s, Epoch: 30, Progress: 58%, Loss: 0.2025]
# EVALUATION: [Time: 0m 0s, Loss: 0.2875, Metrics: 0.9134]
# TRAINING: [Time: 1m 25s, Epoch: 31, Progress: 60%, Loss: 0.1774]
# EVALUATION: [Time: 0m 0s, Loss: 0.3107, Metrics: 0.9056]
# TRAINING: [Time: 1m 28s, Epoch: 32, Progress: 62%, Loss: 0.1736]
# EVALUATION: [Time: 0m 0s, Loss: 0.2644, Metrics: 0.9198]
# TRAINING: [Time: 1m 30s, Epoch: 33, Progress: 64%, Loss: 0.1652]
# EVALUATION: [Time: 0m 0s, Loss: 0.2545, Metrics: 0.9226]
# TRAINING: [Time: 1m 33s, Epoch: 34, Progress: 66%, Loss: 0.1634]
# EVALUATION: [Time: 0m 0s, Loss: 0.2569, Metrics: 0.9213]
# TRAINING: [Time: 1m 36s, Epoch: 35, Progress: 68%, Loss: 0.1751]
# EVALUATION: [Time: 0m 0s, Loss: 0.3257, Metrics: 0.9032]
# TRAINING: [Time: 1m 38s, Epoch: 36, Progress: 70%, Loss: 0.1676]
# EVALUATION: [Time: 0m 0s, Loss: 0.2472, Metrics: 0.9251]
# TRAINING: [Time: 1m 41s, Epoch: 37, Progress: 72%, Loss: 0.1555]
# EVALUATION: [Time: 0m 0s, Loss: 0.2598, Metrics: 0.9215]
# TRAINING: [Time: 1m 44s, Epoch: 38, Progress: 74%, Loss: 0.1619]
# EVALUATION: [Time: 0m 0s, Loss: 0.3513, Metrics: 0.8950]
# TRAINING: [Time: 1m 46s, Epoch: 39, Progress: 76%, Loss: 0.1661]
# EVALUATION: [Time: 0m 0s, Loss: 0.2701, Metrics: 0.9181]
# TRAINING: [Time: 1m 49s, Epoch: 40, Progress: 78%, Loss: 0.1545]
# EVALUATION: [Time: 0m 0s, Loss: 0.2843, Metrics: 0.9147]
# TRAINING: [Time: 1m 52s, Epoch: 41, Progress: 80%, Loss: 0.1613]
# EVALUATION: [Time: 0m 0s, Loss: 0.2506, Metrics: 0.9243]
# TRAINING: [Time: 1m 54s, Epoch: 42, Progress: 82%, Loss: 0.1489]
# EVALUATION: [Time: 0m 0s, Loss: 0.2648, Metrics: 0.9200]
# TRAINING: [Time: 1m 57s, Epoch: 43, Progress: 84%, Loss: 0.1542]
# EVALUATION: [Time: 0m 0s, Loss: 0.2618, Metrics: 0.9207]
# TRAINING: [Time: 2m 0s, Epoch: 44, Progress: 86%, Loss: 0.1558]
# EVALUATION: [Time: 0m 0s, Loss: 0.2583, Metrics: 0.9221]
# TRAINING: [Time: 2m 2s, Epoch: 45, Progress: 88%, Loss: 0.1542]
# EVALUATION: [Time: 0m 0s, Loss: 0.2521, Metrics: 0.9240]
# TRAINING: [Time: 2m 5s, Epoch: 46, Progress: 90%, Loss: 0.1329]
# EVALUATION: [Time: 0m 0s, Loss: 0.2569, Metrics: 0.9216]
# TRAINING: [Time: 2m 8s, Epoch: 47, Progress: 92%, Loss: 0.1323]
# EVALUATION: [Time: 0m 0s, Loss: 0.2547, Metrics: 0.9234]
# TRAINING: [Time: 2m 10s, Epoch: 48, Progress: 94%, Loss: 0.1294]
# EVALUATION: [Time: 0m 0s, Loss: 0.2563, Metrics: 0.9232]
# TRAINING: [Time: 2m 13s, Epoch: 49, Progress: 96%, Loss: 0.1359]
# EVALUATION: [Time: 0m 0s, Loss: 0.2458, Metrics: 0.9256]
# TRAINING: [Time: 2m 16s, Epoch: 50, Progress: 98%, Loss: 0.1308]
# EVALUATION: [Time: 0m 0s, Loss: 0.2490, Metrics: 0.9246]
# Cross validation, fold number 3 in progress...
# TRAINING: [Time: 0m 2s, Epoch: 0, Progress: 0%, Loss: 1.9912]
# EVALUATION: [Time: 0m 0s, Loss: 1.0281, Metrics: 0.6899]
# TRAINING: [Time: 0m 5s, Epoch: 1, Progress: 1%, Loss: 0.8809]
# EVALUATION: [Time: 0m 0s, Loss: 0.7222, Metrics: 0.7790]
# TRAINING: [Time: 0m 7s, Epoch: 2, Progress: 3%, Loss: 0.7096]
# EVALUATION: [Time: 0m 0s, Loss: 0.5335, Metrics: 0.8371]
# TRAINING: [Time: 0m 10s, Epoch: 3, Progress: 5%, Loss: 0.5770]
# EVALUATION: [Time: 0m 0s, Loss: 0.5966, Metrics: 0.8166]
# TRAINING: [Time: 0m 13s, Epoch: 4, Progress: 7%, Loss: 0.6224]
# EVALUATION: [Time: 0m 0s, Loss: 0.5817, Metrics: 0.8216]
# TRAINING: [Time: 0m 15s, Epoch: 5, Progress: 9%, Loss: 0.5120]
# EVALUATION: [Time: 0m 0s, Loss: 0.4588, Metrics: 0.8582]
# TRAINING: [Time: 0m 18s, Epoch: 6, Progress: 11%, Loss: 0.4684]
# EVALUATION: [Time: 0m 0s, Loss: 0.4349, Metrics: 0.8649]
# TRAINING: [Time: 0m 21s, Epoch: 7, Progress: 13%, Loss: 0.4463]
# EVALUATION: [Time: 0m 0s, Loss: 0.7150, Metrics: 0.7813]
# TRAINING: [Time: 0m 23s, Epoch: 8, Progress: 15%, Loss: 0.4160]
# EVALUATION: [Time: 0m 0s, Loss: 0.3883, Metrics: 0.8800]
# TRAINING: [Time: 0m 26s, Epoch: 9, Progress: 17%, Loss: 0.3916]
# EVALUATION: [Time: 0m 0s, Loss: 0.4297, Metrics: 0.8656]
# TRAINING: [Time: 0m 29s, Epoch: 10, Progress: 19%, Loss: 0.3726]
# EVALUATION: [Time: 0m 0s, Loss: 0.3691, Metrics: 0.8864]
# TRAINING: [Time: 0m 31s, Epoch: 11, Progress: 21%, Loss: 0.3450]
# EVALUATION: [Time: 0m 0s, Loss: 0.3186, Metrics: 0.9023]
# TRAINING: [Time: 0m 34s, Epoch: 12, Progress: 23%, Loss: 0.3444]
# EVALUATION: [Time: 0m 0s, Loss: 0.4401, Metrics: 0.8635]
# TRAINING: [Time: 0m 37s, Epoch: 13, Progress: 25%, Loss: 0.3369]
# EVALUATION: [Time: 0m 0s, Loss: 0.3260, Metrics: 0.8995]
# TRAINING: [Time: 0m 39s, Epoch: 14, Progress: 27%, Loss: 0.3241]
# EVALUATION: [Time: 0m 0s, Loss: 0.4581, Metrics: 0.8572]
# TRAINING: [Time: 0m 42s, Epoch: 15, Progress: 29%, Loss: 0.3073]
# EVALUATION: [Time: 0m 0s, Loss: 0.3442, Metrics: 0.8935]
# TRAINING: [Time: 0m 45s, Epoch: 16, Progress: 31%, Loss: 0.2912]
# EVALUATION: [Time: 0m 0s, Loss: 0.3050, Metrics: 0.9062]
# TRAINING: [Time: 0m 48s, Epoch: 17, Progress: 33%, Loss: 0.2768]
# EVALUATION: [Time: 0m 0s, Loss: 0.3738, Metrics: 0.8838]
# TRAINING: [Time: 0m 50s, Epoch: 18, Progress: 35%, Loss: 0.2760]
# EVALUATION: [Time: 0m 0s, Loss: 0.3460, Metrics: 0.8929]
# TRAINING: [Time: 0m 53s, Epoch: 19, Progress: 37%, Loss: 0.2501]
# EVALUATION: [Time: 0m 0s, Loss: 0.2888, Metrics: 0.9113]
# TRAINING: [Time: 0m 56s, Epoch: 20, Progress: 39%, Loss: 0.2446]
# EVALUATION: [Time: 0m 0s, Loss: 0.2756, Metrics: 0.9154]
# TRAINING: [Time: 0m 59s, Epoch: 21, Progress: 41%, Loss: 0.2489]
# EVALUATION: [Time: 0m 0s, Loss: 0.3511, Metrics: 0.8916]
# TRAINING: [Time: 1m 1s, Epoch: 22, Progress: 43%, Loss: 0.2365]
# EVALUATION: [Time: 0m 0s, Loss: 0.2727, Metrics: 0.9158]
# TRAINING: [Time: 1m 4s, Epoch: 23, Progress: 45%, Loss: 0.2367]
# EVALUATION: [Time: 0m 0s, Loss: 0.3502, Metrics: 0.8914]
# TRAINING: [Time: 1m 7s, Epoch: 24, Progress: 47%, Loss: 0.2264]
# EVALUATION: [Time: 0m 0s, Loss: 0.2872, Metrics: 0.9111]
# TRAINING: [Time: 1m 9s, Epoch: 25, Progress: 49%, Loss: 0.2247]
# EVALUATION: [Time: 0m 0s, Loss: 0.2963, Metrics: 0.9082]
# TRAINING: [Time: 1m 12s, Epoch: 26, Progress: 50%, Loss: 0.2214]
# EVALUATION: [Time: 0m 0s, Loss: 0.2702, Metrics: 0.9160]
# TRAINING: [Time: 1m 14s, Epoch: 27, Progress: 52%, Loss: 0.2101]
# EVALUATION: [Time: 0m 0s, Loss: 0.2862, Metrics: 0.9113]
# TRAINING: [Time: 1m 17s, Epoch: 28, Progress: 54%, Loss: 0.2157]
# EVALUATION: [Time: 0m 0s, Loss: 0.3162, Metrics: 0.9028]
# TRAINING: [Time: 1m 20s, Epoch: 29, Progress: 56%, Loss: 0.2098]
# EVALUATION: [Time: 0m 0s, Loss: 0.2880, Metrics: 0.9110]
# TRAINING: [Time: 1m 23s, Epoch: 30, Progress: 58%, Loss: 0.2026]
# EVALUATION: [Time: 0m 0s, Loss: 0.2744, Metrics: 0.9164]
# TRAINING: [Time: 1m 25s, Epoch: 31, Progress: 60%, Loss: 0.1892]
# EVALUATION: [Time: 0m 0s, Loss: 0.4144, Metrics: 0.8711]
# TRAINING: [Time: 1m 28s, Epoch: 32, Progress: 62%, Loss: 0.1850]
# EVALUATION: [Time: 0m 0s, Loss: 0.2679, Metrics: 0.9181]
# TRAINING: [Time: 1m 31s, Epoch: 33, Progress: 64%, Loss: 0.1874]
# EVALUATION: [Time: 0m 0s, Loss: 0.2729, Metrics: 0.9167]
# TRAINING: [Time: 1m 33s, Epoch: 34, Progress: 66%, Loss: 0.1780]
# EVALUATION: [Time: 0m 0s, Loss: 0.3786, Metrics: 0.8831]
# TRAINING: [Time: 1m 36s, Epoch: 35, Progress: 68%, Loss: 0.1734]
# EVALUATION: [Time: 0m 0s, Loss: 0.2894, Metrics: 0.9115]
# TRAINING: [Time: 1m 39s, Epoch: 36, Progress: 70%, Loss: 0.1657]
# EVALUATION: [Time: 0m 0s, Loss: 0.2926, Metrics: 0.9101]
# TRAINING: [Time: 1m 41s, Epoch: 37, Progress: 72%, Loss: 0.1641]
# EVALUATION: [Time: 0m 0s, Loss: 0.3020, Metrics: 0.9070]
# TRAINING: [Time: 1m 44s, Epoch: 38, Progress: 74%, Loss: 0.1574]
# EVALUATION: [Time: 0m 0s, Loss: 0.2598, Metrics: 0.9201]
# TRAINING: [Time: 1m 47s, Epoch: 39, Progress: 76%, Loss: 0.1578]
# EVALUATION: [Time: 0m 0s, Loss: 0.2421, Metrics: 0.9253]
# TRAINING: [Time: 1m 49s, Epoch: 40, Progress: 78%, Loss: 0.1581]
# EVALUATION: [Time: 0m 0s, Loss: 0.2708, Metrics: 0.9160]
# TRAINING: [Time: 1m 52s, Epoch: 41, Progress: 80%, Loss: 0.1631]
# EVALUATION: [Time: 0m 0s, Loss: 0.2469, Metrics: 0.9243]
# TRAINING: [Time: 1m 55s, Epoch: 42, Progress: 82%, Loss: 0.1624]
# EVALUATION: [Time: 0m 0s, Loss: 0.2767, Metrics: 0.9149]
# TRAINING: [Time: 1m 57s, Epoch: 43, Progress: 84%, Loss: 0.1558]
# EVALUATION: [Time: 0m 0s, Loss: 0.2571, Metrics: 0.9233]
# TRAINING: [Time: 2m 0s, Epoch: 44, Progress: 86%, Loss: 0.1554]
# EVALUATION: [Time: 0m 0s, Loss: 0.3291, Metrics: 0.8975]
# TRAINING: [Time: 2m 3s, Epoch: 45, Progress: 88%, Loss: 0.1557]
# EVALUATION: [Time: 0m 0s, Loss: 0.2714, Metrics: 0.9166]
# TRAINING: [Time: 2m 5s, Epoch: 46, Progress: 90%, Loss: 0.1438]
# EVALUATION: [Time: 0m 0s, Loss: 0.2433, Metrics: 0.9245]
# TRAINING: [Time: 2m 8s, Epoch: 47, Progress: 92%, Loss: 0.1363]
# EVALUATION: [Time: 0m 0s, Loss: 0.2467, Metrics: 0.9230]
# TRAINING: [Time: 2m 11s, Epoch: 48, Progress: 94%, Loss: 0.1385]
# EVALUATION: [Time: 0m 0s, Loss: 0.2595, Metrics: 0.9209]
# TRAINING: [Time: 2m 14s, Epoch: 49, Progress: 96%, Loss: 0.1328]
# EVALUATION: [Time: 0m 0s, Loss: 0.2590, Metrics: 0.9201]
# TRAINING: [Time: 2m 16s, Epoch: 50, Progress: 98%, Loss: 0.1372]
# EVALUATION: [Time: 0m 0s, Loss: 0.2343, Metrics: 0.9275]
# Cross validation, fold number 4 in progress...
# TRAINING: [Time: 0m 1s, Epoch: 0, Progress: 0%, Loss: 1.9943]
# EVALUATION: [Time: 0m 0s, Loss: 1.5741, Metrics: 0.5421]
# TRAINING: [Time: 0m 4s, Epoch: 1, Progress: 1%, Loss: 0.9260]
# EVALUATION: [Time: 0m 0s, Loss: 0.6505, Metrics: 0.8077]
# TRAINING: [Time: 0m 6s, Epoch: 2, Progress: 3%, Loss: 0.7138]
# EVALUATION: [Time: 0m 0s, Loss: 0.5684, Metrics: 0.8289]
# TRAINING: [Time: 0m 8s, Epoch: 3, Progress: 5%, Loss: 0.5905]
# EVALUATION: [Time: 0m 0s, Loss: 0.5171, Metrics: 0.8448]
# TRAINING: [Time: 0m 10s, Epoch: 4, Progress: 7%, Loss: 0.5089]
# EVALUATION: [Time: 0m 0s, Loss: 0.4918, Metrics: 0.8532]
# TRAINING: [Time: 0m 12s, Epoch: 5, Progress: 9%, Loss: 0.4905]
# EVALUATION: [Time: 0m 0s, Loss: 0.4735, Metrics: 0.8569]
# TRAINING: [Time: 0m 14s, Epoch: 6, Progress: 11%, Loss: 0.4510]
# EVALUATION: [Time: 0m 0s, Loss: 0.5551, Metrics: 0.8381]
# TRAINING: [Time: 0m 16s, Epoch: 7, Progress: 13%, Loss: 0.4206]
# EVALUATION: [Time: 0m 0s, Loss: 0.4368, Metrics: 0.8699]
# TRAINING: [Time: 0m 19s, Epoch: 8, Progress: 15%, Loss: 0.4085]
# EVALUATION: [Time: 0m 0s, Loss: 0.3556, Metrics: 0.8954]
# TRAINING: [Time: 0m 21s, Epoch: 9, Progress: 17%, Loss: 0.3646]
# EVALUATION: [Time: 0m 0s, Loss: 0.3557, Metrics: 0.8943]
# TRAINING: [Time: 0m 23s, Epoch: 10, Progress: 19%, Loss: 0.3514]
# EVALUATION: [Time: 0m 0s, Loss: 0.3933, Metrics: 0.8839]
# TRAINING: [Time: 0m 25s, Epoch: 11, Progress: 21%, Loss: 0.3167]
# EVALUATION: [Time: 0m 0s, Loss: 0.3197, Metrics: 0.9055]
# TRAINING: [Time: 0m 27s, Epoch: 12, Progress: 23%, Loss: 0.3059]
# EVALUATION: [Time: 0m 0s, Loss: 0.3497, Metrics: 0.8962]
# TRAINING: [Time: 0m 30s, Epoch: 13, Progress: 25%, Loss: 0.3171]
# EVALUATION: [Time: 0m 0s, Loss: 0.4381, Metrics: 0.8685]
# TRAINING: [Time: 0m 32s, Epoch: 14, Progress: 27%, Loss: 0.2835]
# EVALUATION: [Time: 0m 0s, Loss: 0.3105, Metrics: 0.9074]
# TRAINING: [Time: 0m 34s, Epoch: 15, Progress: 29%, Loss: 0.2874]
# EVALUATION: [Time: 0m 0s, Loss: 0.3075, Metrics: 0.9092]
# TRAINING: [Time: 0m 36s, Epoch: 16, Progress: 31%, Loss: 0.2626]
# EVALUATION: [Time: 0m 0s, Loss: 0.3773, Metrics: 0.8887]
# TRAINING: [Time: 0m 38s, Epoch: 17, Progress: 33%, Loss: 0.2586]
# EVALUATION: [Time: 0m 0s, Loss: 0.3665, Metrics: 0.8914]
# TRAINING: [Time: 0m 40s, Epoch: 18, Progress: 35%, Loss: 0.2455]
# EVALUATION: [Time: 0m 0s, Loss: 0.3346, Metrics: 0.9006]
# TRAINING: [Time: 0m 43s, Epoch: 19, Progress: 37%, Loss: 0.2286]
# EVALUATION: [Time: 0m 0s, Loss: 0.2848, Metrics: 0.9146]
# TRAINING: [Time: 0m 45s, Epoch: 20, Progress: 39%, Loss: 0.2321]
# EVALUATION: [Time: 0m 0s, Loss: 0.4377, Metrics: 0.8697]
# TRAINING: [Time: 0m 47s, Epoch: 21, Progress: 41%, Loss: 0.2360]
# EVALUATION: [Time: 0m 0s, Loss: 0.2941, Metrics: 0.9120]
# TRAINING: [Time: 0m 49s, Epoch: 22, Progress: 43%, Loss: 0.2344]
# EVALUATION: [Time: 0m 0s, Loss: 0.2970, Metrics: 0.9120]
# TRAINING: [Time: 0m 51s, Epoch: 23, Progress: 45%, Loss: 0.2278]
# EVALUATION: [Time: 0m 0s, Loss: 0.2850, Metrics: 0.9159]
# TRAINING: [Time: 0m 53s, Epoch: 24, Progress: 47%, Loss: 0.2157]
# EVALUATION: [Time: 0m 0s, Loss: 0.2531, Metrics: 0.9245]
# TRAINING: [Time: 0m 56s, Epoch: 25, Progress: 49%, Loss: 0.5810]
# EVALUATION: [Time: 0m 0s, Loss: 0.5155, Metrics: 0.8465]
# TRAINING: [Time: 0m 58s, Epoch: 26, Progress: 50%, Loss: 0.3255]
# EVALUATION: [Time: 0m 0s, Loss: 0.3108, Metrics: 0.9084]
# TRAINING: [Time: 1m 0s, Epoch: 27, Progress: 52%, Loss: 0.2801]
# EVALUATION: [Time: 0m 0s, Loss: 0.3380, Metrics: 0.8987]
# TRAINING: [Time: 1m 2s, Epoch: 28, Progress: 54%, Loss: 0.2535]
# EVALUATION: [Time: 0m 0s, Loss: 0.2970, Metrics: 0.9119]
# TRAINING: [Time: 1m 4s, Epoch: 29, Progress: 56%, Loss: 0.2429]
# EVALUATION: [Time: 0m 0s, Loss: 0.2851, Metrics: 0.9157]
# TRAINING: [Time: 1m 7s, Epoch: 30, Progress: 58%, Loss: 0.2288]
# EVALUATION: [Time: 0m 0s, Loss: 0.2892, Metrics: 0.9139]
# TRAINING: [Time: 1m 9s, Epoch: 31, Progress: 60%, Loss: 0.2202]
# EVALUATION: [Time: 0m 0s, Loss: 0.2988, Metrics: 0.9100]
# TRAINING: [Time: 1m 11s, Epoch: 32, Progress: 62%, Loss: 0.1971]
# EVALUATION: [Time: 0m 0s, Loss: 0.3184, Metrics: 0.9039]
# TRAINING: [Time: 1m 13s, Epoch: 33, Progress: 64%, Loss: 0.1895]
# EVALUATION: [Time: 0m 0s, Loss: 0.2678, Metrics: 0.9199]
# TRAINING: [Time: 1m 15s, Epoch: 34, Progress: 66%, Loss: 0.1810]
# EVALUATION: [Time: 0m 0s, Loss: 0.3009, Metrics: 0.9104]
# TRAINING: [Time: 1m 18s, Epoch: 35, Progress: 68%, Loss: 0.1882]
# EVALUATION: [Time: 0m 0s, Loss: 0.2985, Metrics: 0.9110]
# TRAINING: [Time: 1m 20s, Epoch: 36, Progress: 70%, Loss: 0.1705]
# EVALUATION: [Time: 0m 0s, Loss: 0.3213, Metrics: 0.9039]
# TRAINING: [Time: 1m 22s, Epoch: 37, Progress: 72%, Loss: 0.1768]
# EVALUATION: [Time: 0m 0s, Loss: 0.2825, Metrics: 0.9157]
# TRAINING: [Time: 1m 24s, Epoch: 38, Progress: 74%, Loss: 0.1874]
# EVALUATION: [Time: 0m 0s, Loss: 0.3045, Metrics: 0.9099]
# TRAINING: [Time: 1m 26s, Epoch: 39, Progress: 76%, Loss: 0.1799]
# EVALUATION: [Time: 0m 0s, Loss: 0.2659, Metrics: 0.9206]
# TRAINING: [Time: 1m 28s, Epoch: 40, Progress: 78%, Loss: 0.1761]
# EVALUATION: [Time: 0m 0s, Loss: 0.3168, Metrics: 0.9049]
# TRAINING: [Time: 1m 30s, Epoch: 41, Progress: 80%, Loss: 0.1654]
# EVALUATION: [Time: 0m 0s, Loss: 0.2768, Metrics: 0.9182]
# TRAINING: [Time: 1m 33s, Epoch: 42, Progress: 82%, Loss: 0.1656]
# EVALUATION: [Time: 0m 0s, Loss: 0.2691, Metrics: 0.9205]
# TRAINING: [Time: 1m 35s, Epoch: 43, Progress: 84%, Loss: 0.1736]
# EVALUATION: [Time: 0m 0s, Loss: 0.3491, Metrics: 0.8974]
# TRAINING: [Time: 1m 37s, Epoch: 44, Progress: 86%, Loss: 0.1655]
# EVALUATION: [Time: 0m 0s, Loss: 0.2664, Metrics: 0.9207]
# TRAINING: [Time: 1m 39s, Epoch: 45, Progress: 88%, Loss: 0.1667]
# EVALUATION: [Time: 0m 0s, Loss: 0.2923, Metrics: 0.9135]
# TRAINING: [Time: 1m 41s, Epoch: 46, Progress: 90%, Loss: 0.1525]
# EVALUATION: [Time: 0m 0s, Loss: 0.2652, Metrics: 0.9216]
# TRAINING: [Time: 1m 43s, Epoch: 47, Progress: 92%, Loss: 0.1402]
# EVALUATION: [Time: 0m 0s, Loss: 0.3132, Metrics: 0.9063]
# TRAINING: [Time: 1m 45s, Epoch: 48, Progress: 94%, Loss: 0.1558]
# EVALUATION: [Time: 0m 0s, Loss: 0.2650, Metrics: 0.9214]
# TRAINING: [Time: 1m 48s, Epoch: 49, Progress: 96%, Loss: 0.1464]
# EVALUATION: [Time: 0m 0s, Loss: 0.2829, Metrics: 0.9160]
# TRAINING: [Time: 1m 50s, Epoch: 50, Progress: 98%, Loss: 0.1354]
# EVALUATION: [Time: 0m 0s, Loss: 0.2619, Metrics: 0.9223]

# %% [markdown]
# ## Evaluating the models

# %%
import numpy as np
rmse = []
r2_score = []
for i in range(5):
    test_dataset = SmilesDataset('./data/logp_test_fold' + str(i) + '.smi',
                                 delimiter=',', cols_to_read=[0, 1], tokens=tokens)
    val_loader = create_loader(test_dataset,
                               batch_size=model_params['batch_size'],
                               shuffle=False,
                               num_workers=1,
                               pin_memory=True)
    metrics = evaluate(models[i], val_loader, criterion)
    rmse.append(np.sqrt(metrics[0]))
    r2_score.append(metrics[1])
# Out:
# EVALUATION: [Time: 0m 0s, Loss: 0.2627, Metrics: 0.9192]
# EVALUATION: [Time: 0m 0s, Loss: 0.2313, Metrics: 0.9334]
# EVALUATION: [Time: 0m 0s, Loss: 0.2490, Metrics: 0.9246]
# EVALUATION: [Time: 0m 0s, Loss: 0.2343, Metrics: 0.9275]
# EVALUATION: [Time: 0m 0s, Loss: 0.2619, Metrics: 0.9223]

# %%
print("Cross-validated RMSE: ",  np.mean(rmse))
print("Cross-validated R^2 score: ", np.mean(r2_score))
# Out:
# Cross-validated RMSE:  0.49763956473190146
# Cross-validated R^2 score:  0.9254044340191147
